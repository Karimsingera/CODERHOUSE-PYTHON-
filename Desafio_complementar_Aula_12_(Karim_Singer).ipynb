# %% [markdown]
# <a href="https://colab.research.google.com/github/Karimsingera/CODERHOUSE-PYTHON-/blob/main/Desafio_complementar_Aula_12_(Karim_Singer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Realtime Weather API

import requests

url = "https://weatherapi-com.p.rapidapi.com/current.json"

querystring = {"q":"Uruçuca"}

headers = {
	"X-RapidAPI-Key": "50ad230a8emsh47e561f64390d87p126316jsnf491652a31de",
	"X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'location': {'name': 'Uruçuca', 'region': 'Bahia', 'country': 'Brésil', 'lat': -14.58, 'lon': -39.27, 'tz_id': 'America/Bahia', 'localtime_epoch': 1701911516, 'localtime': '2023-12-06 22:11'}, 'current': {'last_updated_epoch': 1701910800, 'last_updated': '2023-12-06 22:00', 'temp_c': 20.2, 'temp_f': 68.3, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 187, 'wind_dir': 'S', 'pressure_mb': 1016.0, 'pressure_in': 30.0, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 98, 'cloud': 100, 'feelslike_c': 20.2, 'feelslike_f': 68.3, 'vis_km': 0.0, 'vis_miles': 0.0, 'uv': 1.0, 'gust_mph': 6.7, 'gust_kph': 10.8}}

# %%
# Forecast Weather API

import requests

url = "https://weatherapi-com.p.rapidapi.com/forecast.json"

querystring = {"q":"Uruçuca","days":"3","lang":"pt"}

headers = {
	"X-RapidAPI-Key": "50ad230a8emsh47e561f64390d87p126316jsnf491652a31de",
	"X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'location': {'name': 'Uruçuca', 'region': 'Bahia', 'country': 'Brésil', 'lat': -14.58, 'lon': -39.27, 'tz_id': 'America/Bahia', 'localtime_epoch': 1701911522, 'localtime': '2023-12-06 22:12'}, 'current': {'last_updated_epoch': 1701910800, 'last_updated': '2023-12-06 22:00', 'temp_c': 20.2, 'temp_f': 68.3, 'is_day': 0, 'condition': {'text': 'Nevoeiro', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 187, 'wind_dir': 'S', 'pressure_mb': 1016.0, 'pressure_in': 30.0, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 98, 'cloud': 100, 'feelslike_c': 20.2, 'feelslike_f': 68.3, 'vis_km': 0.0, 'vis_miles': 0.0, 'uv': 1.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'forecast': {'forecastday': [{'date': '2023-12-06', 'date_epoch': 1701820800, 'day': {'maxtemp_c': 32.9, 'maxtemp_f': 91.2, 'mintemp_c': 19.3, 'mintemp_f': 66.7, 'avgtemp_c': 25.0, 'avgtemp_f': 76.9, 'maxwind_mph': 9.2, 'maxwind_kph': 14.8, 'totalprecip_mm': 0.83, 
# ...

# %%
# History Weather API

import requests

url = "https://weatherapi-com.p.rapidapi.com/history.json"

querystring = {"q":"Uruçuca","dt":"2023-12-06","lang":"pt"}

headers = {
	"X-RapidAPI-Key": "50ad230a8emsh47e561f64390d87p126316jsnf491652a31de",
	"X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'location': {'name': 'Uruçuca', 'region': 'Bahia', 'country': 'Brésil', 'lat': -14.58, 'lon': -39.27, 'tz_id': 'America/Bahia', 'localtime_epoch': 1701911526, 'localtime': '2023-12-06 22:12'}, 'forecast': {'forecastday': [{'date': '2023-12-06', 'date_epoch': 1701820800, 'day': {'maxtemp_c': 31.4, 'maxtemp_f': 88.6, 'mintemp_c': 19.5, 'mintemp_f': 67.1, 'avgtemp_c': 24.9, 'avgtemp_f': 76.8, 'maxwind_mph': 8.1, 'maxwind_kph': 13.0, 'totalprecip_mm': 2.26, 'totalprecip_in': 0.09, 'avgvis_km': 8.8, 'avgvis_miles': 5.0, 'avghumidity': 76.0, 'condition': {'text': 'Aguaceiros fracos', 'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png', 'code': 1240}, 'uv': 7.0}, 'astro': {'sunrise': '04:59 AM', 'sunset': '05:57 PM', 'moonrise': '12:24 AM', 'moonset': '12:35 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': 43}, 'hour': [{'time_epoch': 1701831600, 'time': '2023-12-06 00:00', 'temp_c': 21.0, 'temp_f': 69.7, 'is_day': 0, 'condition': {'text': 'Neblina', 'icon': '//cdn.weatherap
# ...

# %%
# Criar um alerta de erro usando a função alerta()]
# Ainga não consego experimentar con plyer no meu computador

from plyer import notification

def alerta(titulo, mensagem):
    notification.notify(
        title=titulo,
        message=mensagem,
        app_name='Alerta de Erro',
        timeout=10,
    )

alerta("Erro na tarefa", "Houve um problema ao extrair as tabelas. Verifique a API e o processo de extração.")
