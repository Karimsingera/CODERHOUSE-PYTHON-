# %% [markdown]
# <a href="https://colab.research.google.com/github/Karimsingera/CODERHOUSE-PYTHON-/blob/main/Desafio_Nintendo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# desafio Nintendo. Alumno: Karim Singer

# %%
# Importar libreria Pandas
import pandas as pd

# %%
# Abra o arquivo "best-selling game consoles.xlsx" em um dataframe.

df = pd.read_excel('/content/best-selling game consoles.xlsx', sheet_name = 'consoles')

df.head()
# Out:
#       Console Name      Type   Company  Released Year  Discontinuation Year  \
# 0    PlayStation 2      Home      Sony           2000                  2013
# 1      Nintendo DS  Handheld  Nintendo           2004                  2013
# 2  Nintendo Switch    Hybrid  Nintendo           2017                     0
# 3         Game Boy  Handheld  Nintendo           1989                  2003
# 4   Game Boy Color  Handheld  Nintendo           1998                  2003
#
#    Units sold (million)                                            Remarks
# 0                155.00           Final sales are greater than 155 million
# 1                154.02                                                NaN
# 2                122.55                                                NaN
# 3                 64.42  The Game Boy (1989) and the Game Boy Color (19...
# 4                 44.06                                                NaN

# %%
# Substitua a palavra "NES" por "Nitendinho" no nome dos consoles e deixe todos os nomes em maiúsculos.

df['Console Name'] = df['Console Name'].str.replace('NES','Nitendinho').str.upper()

df.head(40)
# Out:
#                          Console Name                 Type  \
# 0                       PLAYSTATION 2                 Home
# 1                         NINTENDO DS             Handheld
# 2                     NINTENDO SWITCH               Hybrid
# 3                            GAME BOY             Handheld
# 4                      GAME BOY COLOR             Handheld
# 5                       PLAYSTATION 4                 Home
# 6                         PLAYSTATION                 Home
# 7                                 WII                 Home
# 8                       PLAYSTATION 3                 Home
# 9                            XBOX 360                 Home
# 10                   GAME BOY ADVANCE             Handheld
# 11               PLAYSTATION PORTABLE             Handheld
# 12                       NINTENDO 3DS             Handheld
# 13                 NITENDINHO/FAMICOM                 Home
# 14                           XBOX ONE                 Home
# ...

# %%
# Filtre o nome dos consoles com data de release depois de 2010.


df.loc[df['Released Year'] > 2010,['Console Name', 'Released Year']]
# Out:
#                         Console Name  Released Year
# 2                    NINTENDO SWITCH           2017
# 5                      PLAYSTATION 4           2013
# 12                      NINTENDO 3DS           2011
# 14                          XBOX ONE           2013
# 19                     PLAYSTATION 5           2020
# 23                   XBOX SERIES X/S           2020
# 24                             WII U           2012
# 25                  PLAYSTATION VITA           2011
# 33  SUPER NITENDINHO CLASSIC EDITION           2017
# 35        NITENDINHO CLASSIC EDITION           2016

# %%
# De um describe e info da base

df.describe()
# Out:
#        Released Year  Discontinuation Year  Units sold (million)
# count      51.000000             51.000000             51.000000
# mean     1996.058824           1844.803922             35.549412
# std        12.378064            543.657319             42.608844
# min      1976.000000              0.000000              1.000000
# 25%      1987.500000           1992.000000              3.200000
# 50%      1994.000000           1998.000000             13.560000
# 75%      2004.500000           2011.500000             60.205000
# max      2020.000000           2020.000000            155.000000

# %%
# De um describe e info da base

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Console Name          51 non-null     object
#  1   Type                  51 non-null     object
#  2   Company               51 non-null     object
#  3   Released Year         51 non-null     int64
#  4   Discontinuation Year  51 non-null     int64
#  5   Units sold (million)  51 non-null     float64
#  6   Remarks               16 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
# substitua os missing values pela string "missing".

df = df.fillna('missing')

df.isnull()
# Out:
#     Console Name   Type  Company  Released Year  Discontinuation Year  \
# 0          False  False    False          False                 False
# 1          False  False    False          False                 False
# 2          False  False    False          False                 False
# 3          False  False    False          False                 False
# 4          False  False    False          False                 False
# 5          False  False    False          False                 False
# 6          False  False    False          False                 False
# 7          False  False    False          False                 False
# 8          False  False    False          False                 False
# 9          False  False    False          False                 False
# 10         False  False    False          False                 False
# 11         False  False    False          False                 False
# ...

# %%
# Filtre os consoles que foram descontinuados a menos de 2 anos da data de release.

df_filtrado = df['Discontinuation Year'] - df['Released Year']

df.loc[(df_filtrado <= 2) & (df_filtrado > 0),
             ['Console Name','Released Year','Discontinuation Year']]
# Out:
#                         Console Name  Released Year  Discontinuation Year
# 33  SUPER NITENDINHO CLASSIC EDITION           2017                  2018
# 35        NITENDINHO CLASSIC EDITION           2016                  2018
# 41                            N-GAGE           2003                  2005
# 49                           TELSTAR           1976                  1978
# 50                        ATARI 5200           1982                  1984
